# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
re_data = pd.read_csv("Real estate.csv", usecols=range(1,8))
re_data.head()
# Out:
#    X1 transaction date  X2 house age  X3 distance to the nearest MRT station  \
# 0             2012.917          32.0                                84.87882
# 1             2012.917          19.5                               306.59470
# 2             2013.583          13.3                               561.98450
# 3             2013.500          13.3                               561.98450
# 4             2012.833           5.0                               390.56840
#
#    X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                               10     24.98298     121.54024
# 1                                9     24.98034     121.53951
# 2                                5     24.98746     121.54391
# 3                                5     24.98746     121.54391
# 4                                5     24.97937     121.54245
#
#    Y house price of unit area
# 0                        37.9
# 1                        42.2
# 2                        47.3
# 3                        54.8
# 4                        43.1

# %%
re_data.rename(columns = {'X1 transaction date' : 'Transaction date', 
                                   'X2 house age' : 'House age',
                                   'X3 distance to the nearest MRT station' : 'Distance to the nearest MRT station',
                                   'X4 number of convenience stores' : 'Number of convenience stores',
                                   'X5 latitude' : 'Latitude',
                                   'X6 longitude' : 'Longitude',
                                   'Y house price of unit area' : 'House price of unit area'}, inplace = True)

# %%
X = re_data.drop(columns = ['House price of unit area'])
y = re_data['House price of unit area']

print(X.shape)
print(y.shape)
# Out:
# (414, 6)
# (414,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(X, y, random_state=42)

lr = LinearRegression().fit(X_train, y_train)

# %%
print("Training score: {:.2f}".format(lr.score(X_train, y_train)))
print("Validation score: {:.2f}".format(lr.score(X_val, y_val)))
# Out:
# Training score: 0.58
# Validation score: 0.58

# %%
from sklearn.linear_model import Ridge

ridge = Ridge().fit(X_train, y_train)
print("Training score: {:.2f}".format(ridge.score(X_train, y_train)))
print("Validation score: {:.2f}".format(ridge.score(X_val, y_val)))
# Out:
# Training score: 0.55
# Validation score: 0.56

# %%
ridge10 = Ridge(alpha=10).fit(X_train, y_train)
print("Training score: {:.2f}".format(ridge10.score(X_train, y_train)))
print("Validation score: {:.2f}".format(ridge10.score(X_val, y_val)))
# Out:
# Training score: 0.55
# Validation score: 0.56

# %%
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures(degree=5, interaction_only=True)
X_new = poly.fit_transform(X)
print(X_new.shape)
# Out:
# (414, 63)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_new, y, random_state=42)

lr = LinearRegression().fit(X_train, y_train)
print("Training score: {:.2f}".format(lr.score(X_train, y_train)))
print("Validation score: {:.2f}".format(lr.score(X_val, y_val)))
# Out:
# Training score: 0.73
# Validation score: 0.59

# %%
ridge = Ridge().fit(X_train, y_train)
print("Training score: {:.2f}".format(ridge.score(X_train, y_train)))
print("Validation score: {:.2f}".format(ridge.score(X_val, y_val)))
# Out:
# Training score: 0.72
# Validation score: 0.67

# %%
ridge10 = Ridge(alpha=10).fit(X_train, y_train)
print("Training score: {:.2f}".format(ridge10.score(X_train, y_train)))
print("Validation score: {:.2f}".format(ridge10.score(X_val, y_val)))
# Out:
# Training score: 0.71
# Validation score: 0.69
# C:\Users\ladawson\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=6.895e-25): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T

# %%
ridge01 = Ridge(alpha=0.1).fit(X_train, y_train)
print("Training score: {:.2f}".format(ridge01.score(X_train, y_train)))
print("Validation score: {:.2f}".format(ridge01.score(X_val, y_val)))
# Out:
# Training score: 0.72
# Validation score: 0.66
